# %%
import scrapy

# %%
class MySpider(scrapy.Spider):
    name='myspider'
    allowed_domains=['toscrape.com']
    start_urls=['https://books.toscrape.com/']
    
    def parse(self,response):
        for container in response.xpath('//article[@class="product_pod"]'):
            image_link=response.xpath('//div[@class="image_container"]/a/img/@src').get()
            price=container.xpath('.//p[@class="price_color"]/text()').get('').strip()
            link=container.xpath('.//div[@class="image_container"]/a/@href').get()
            title=container.xpath('.//h3/a/text()').get()
            yield{'image_link':image_link,
                 'price':price,
                 'link':link,
                 'title':title}

# %%
from scrapy.crawler import CrawlerProcess
process=CrawlerProcess(settings={'FEEDS':{'output.csv':{'format':'csv'}}})
process.crawl(MySpider)
process.start()
# Out:
# 2024-08-03 19:48:45 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2024-08-03 19:48:45 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 23.0.0 (OpenSSL 1.1.1t  7 Feb 2023), cryptography 39.0.1, Platform Windows-10-10.0.22631-SP0
# 2024-08-03 19:48:45 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2024-08-03 19:48:45 [py.warnings] WARNING: C:\Users\HP\anaconda3\lib\site-packages\scrapy\utils\request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\HP\\3D Projects\\Untitled Folder 1'

# %%
import pandas as pd
from IPython.display import display, HTML

# Read the CSV file
df = pd.read_csv('output.csv')

# Convert image link to actual image
df['image_link'] = '<img src="' + df['image_link'] + '" width="60"/>'

# Convert DataFrame to HTML with custom styles
html_table = df.to_html(escape=False, render_links=True, index=False, classes='table table-striped')

# Display the HTML table
display(HTML(html_table))
# Out:
# Unhandled error in Deferred:
# 2024-08-03 20:02:51 [twisted] CRITICAL: Unhandled error in Deferred:
# 2024-08-03 20:02:51 [twisted] CRITICAL: Unhandled error in Deferred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\lib\site-packages\scrapy\crawler.py", line 233, in crawl
#     return self._crawl(crawler, *args, **kwargs)
#   File "C:\Users\HP\anaconda3\lib\site-packages\scrapy\crawler.py", line 237, in _crawl
#     d = crawler.crawl(*args, **kwargs)
#   File "C:\Users\HP\anaconda3\lib\site-packages\twisted\internet\defer.py", line 1905, in unwindGenerator
#     return _cancellableInlineCallbacks(gen)
#   File "C:\Users\HP\anaconda3\lib\site-packages\twisted\internet\defer.py", line 1815, in _cancellableInlineCallbacks
#     _inlineCallbacks(None, gen, status)
# --- <exception caught here> ---
#   File "C:\Users\HP\anaconda3\lib\site-packages\twisted\internet\defer.py", line 1660, in _inlineCallbacks
#     result = current_context.run(gen.send, result)
# ...

# %%
df = pd.read_csv('output.csv')
df
# Out:
#                                            image_link   price  \
# 0   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £51.77
# 1   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £53.74
# 2   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £50.10
# 3   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £47.82
# 4   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £54.23
# 5   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £22.65
# 6   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £33.34
# 7   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £17.93
# 8   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £22.60
# 9   media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £52.15
# 10  media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £13.99
# 11  media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £20.66
# 12  media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £17.46
# 13  media/cache/2c/da/2cdad67c44b002e7ead0cc35693c...  £52.29
# ...
